# %% [markdown]
# <a href="https://colab.research.google.com/github/MBR4V0/Python/blob/main/Teste_Radm_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
"Aqui pode-se consultar as pastas que tem no arquivo DRIVE"
os.listdir('/content/drive/MyDrive')

# %%
os.listdir('/content/drive/MyDrive/Dados_teste')
# Out:
# ['dados.xlsx']

# %% [markdown]
# **Etapa 9 — Instalar/importar o Pandas**

# %%
import pandas as pd

# %%
df = pd.read_excel(
    '/content/drive/MyDrive/Dados_teste/dados.xlsx'
)

# %%
df.head()
# Out:
#    Idade  Tumor_cm  Linfonodos  Ki67  TN
# 0     45       2.1           3    70   1
# 1     62       1.2           0    15   0
# 2     51       3.4           5    80   1
# 3     39       1.5           1    25   0
# 4     58       2.8           4    65   1

# %% [markdown]
# E se você quiser trabalhar com um Excel que está no seu computador?

# %%
"from google.colab import files"

"arquivo = files.upload()"
# Out:
# 'arquivo = files.upload()'

# %%
df.head()
# Out:
#    Idade  Tumor_cm  Linfonodos  Ki67  TN
# 0     45       2.1           3    70   1
# 1     62       1.2           0    15   0
# 2     51       3.4           5    80   1
# 3     39       1.5           1    25   0
# 4     58       2.8           4    65   1

# %%
df.shape
# Out:
# (8, 5)

# %% [markdown]
# **Random Forest**

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
X = df[['Idade', 'Tumor_cm', 'Linfonodos', 'Ki67']]

# %%
y = df['TN']

# %%
print("X:")
display(X)

print("y:")
display(y)
# Out:
# X:
#    Idade  Tumor_cm  Linfonodos  Ki67
# 0     45       2.1           3    70
# 1     62       1.2           0    15
# 2     51       3.4           5    80
# 3     39       1.5           1    25
# 4     58       2.8           4    65
# 5     67       1.1           0    10
# 6     43       2.9           3    75
# 7     55       1.8           1    30
# y:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# 5    0
# 6    1
# 7    0
# Name: TN, dtype: int64

# %% [markdown]
# **Separar treinamento e teste (70% dos dados para ensinar o modelo e 30% para testar.)**

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(
    X,
    y,
    test_size=0.30,
    random_state=42
)

# %%
print("Treinamento:", len(X_treino))
print("Teste:", len(X_teste))
# Out:
# Treinamento: 5
# Teste: 3

# %% [markdown]
# **Criar o Random Forest**

# %%
modelo_rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

# %%
n_estimators=100

# %% [markdown]
# **Treinar**

# %%
modelo_rf.fit(
    X_treino,
    y_treino
)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# **Fazer as previsões**

# %%
previsao_rf = modelo_rf.predict(
    X_teste
)

# %% [markdown]
# **Comparar previsão com realidade**

# %%
print("Real:")
print(y_teste.values)

print()

print("Previsão:")
print(previsao_rf)
# Out:
# Real:
# [0 0 1]
#
# Previsão:
# [0 0 1]

# %% [markdown]
# **Calcular a acurácia**

# %%
acuracia_rf = accuracy_score(
    y_teste,
    previsao_rf
)

# %%
print(
    f"Acurácia Random Forest: {acuracia_rf:.2%}"
)
# Out:
# Acurácia Random Forest: 100.00%
